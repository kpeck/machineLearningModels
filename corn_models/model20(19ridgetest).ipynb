# %%
#importazione dei dati ------------------------------------------------------------------------------------------------------------

from pandas import DataFrame
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy.linalg import toeplitz
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_validate

df = pd.read_csv (r'/Users/patrickpinta/Desktop/1datasetpanda/corn.csv',header=0,error_bad_lines=False) 

#modellazione dei dati training set------------------------------------------------------------------------------------------------------------
xExpUsa= df.iloc[0:334,1:2]
xExpUsa = np.array(xExpUsa)
xExpEu=df.iloc[0:334,3:4]
xExpEu = np.array(xExpEu)
xImportChina=xExpUsa+xExpEu

polynomial_features= PolynomialFeatures(degree=2)
xImportChina = polynomial_features.fit_transform(xImportChina)

xBimestri=df.iloc[0:334,13:18]
xBimestri = np.array(xBimestri)

xUsa=df.iloc[0:334,0:1]
xUsa = np.array(xUsa)
xBimInfExpUsa=xBimestri*xUsa

xEu=df.iloc[0:334,1:2]
xEu = np.array(xEu)
xBimInfExpEu=xBimestri*xEu

xPrecUsa=df.iloc[0:334,7:8]
xPrecUsa = np.array(xPrecUsa)
xBimInfPrecUsa=xBimestri*xPrecUsa

xPrecEu=df.iloc[0:334,9:10]
xPrecEu = np.array(xPrecEu)
xBimInfPrecEu=xBimestri*xPrecEu

xTempUsa=df.iloc[0:334,8:9]
xTempUsa = np.array(xTempUsa)
xBimInfTempUsa=xBimestri*xTempUsa

xTempEu=df.iloc[0:334,10:11]
xTempEu = np.array(xTempEu)
xBimInfTempEu=xBimestri*xTempEu

xOpenInterest=df.iloc[0:334,4:5]
xOpenInterest = np.array(xOpenInterest)
xBimInfOpenInterest=xBimestri*xOpenInterest

x= df.iloc[0:334,0:1]
x1= df.iloc[0:334,2:3]
x2= df.iloc[0:334,4:5] #openInterest
x3= df.iloc[0:334,6:11]
x4= df.iloc[0:334,11:12] #stockWorld
x5= df.iloc[0:334,12:13] #stockUsa
x6= df.iloc[0:334,13:18]

polynomial_features= PolynomialFeatures(degree=2)
x = polynomial_features.fit_transform(x)

polynomial_features= PolynomialFeatures(degree=2)
x1 = polynomial_features.fit_transform(x1)

polynomial_features= PolynomialFeatures(degree=3)
x2 = polynomial_features.fit_transform(x2)

polynomial_features= PolynomialFeatures(degree=3)
x4 = polynomial_features.fit_transform(x4)

polynomial_features= PolynomialFeatures(degree=3)
x5 = polynomial_features.fit_transform(x5)



xImportChina=xImportChina.tolist()
xImportChina = DataFrame (xImportChina,columns=['ImportChina','ImportChina1','ImportChina2'])

x=x.tolist()
x = DataFrame (x,columns=['expUsa','expUsa1','expUsa2'])

x1=x1.tolist()
x1 = DataFrame (x1,columns=['expEu','expEu1','expEu2'])

x2=x2.tolist()
x2 = DataFrame (x2,columns=['openInt','openInt1','openInt2','openInt3'])

x4=x4.tolist()
x4 = DataFrame (x4,columns=['sw','sw1','sw2','sw3'])

x5=x5.tolist()
x5 = DataFrame (x5,columns=['su','su1','su2','su3'])

xBimInfExpUsa=xBimInfExpUsa.tolist()
xBimInfExpUsa = DataFrame (xBimInfExpUsa,columns=['bim1*expUsa','bim2*expUsa','bim3*expUsa','bim4*expUsa','bim5*expUsa'])
xBimInfExpEU=xBimInfExpEu.tolist()
xBimInfExpEu = DataFrame (xBimInfExpEu,columns=['bim1*expEu','bim2*expEu','bim3*expEu','bim4*expEu','bim5*expEu'])

xBimInfPrecUsa=xBimInfPrecUsa.tolist()
xBimInfPrecUsa = DataFrame (xBimInfPrecUsa,columns=['bim1*precUsa','bim2*precUsa','bim3*precUsa','bim4*precUsa','bim5*precUsa'])
xBimInfPrecEu=xBimInfPrecEu.tolist()
xBimInfPrecEu = DataFrame (xBimInfPrecEu,columns=['bim1*precEu','bim2*precEu','bim3*precEu','bim4*precEu','bim5*precEu'])

xBimInfTempUsa=xBimInfTempUsa.tolist()
xBimInfTempUsa = DataFrame (xBimInfTempUsa,columns=['bim1*tempUsa','bim2*tempUsa','bim3*tempUsa','bim4*tempUsa','bim5*tempUsa'])
xBimInfTempEu=xBimInfTempEu.tolist()
xBimInfTempEu = DataFrame (xBimInfTempEu,columns=['bim1*tempEu','bim2*tempEu','bim3*tempEu','bim4*tempEu','bim5*tempEu'])

xBimInfOpenInterest=xBimInfOpenInterest.tolist()
xBimInfOpenInterest = DataFrame (xBimInfOpenInterest,columns=['bim1*openInterest','bim2*openInterest','bim3*openInterest','bim4*openInterest','bim5*openInterest'])

x=x.iloc[0:334,1:2]
x=x.join(xImportChina.iloc[0:334,1:2])
x=x.join(x1.iloc[0:334,1:2])
x=x.join(x2.iloc[0:334,1:4])
x=x.join(x3)
x=x.join(x4.iloc[0:334,1:4])
x=x.join(x5.iloc[0:334,1:4])
x=x.join(x6)
x=x.join(xBimInfExpUsa)
x=x.join(xBimInfExpEu)
#x=x.join(xBimInfPrecUsa)
#x=x.join(xBimInfPrecEu)
#x=x.join(xBimInfTempUsa)
#x=x.join(xBimInfTempEu)
x=x.join(xBimInfOpenInterest)



y= df.iloc[0:334,19:20]

#print(x)

#stardadizzazione dei dati training set------------------------------------------------------------------------------------------------------------

scaler = MinMaxScaler(feature_range=(-1,1))

x_train_stand=(scaler.fit_transform(x))
    
#modello dati training set------------------------------------------------------------------------------------------------------------    
    
x_train_stand, y = np.array(x_train_stand), np.array(y)
x_train_stand = sm.add_constant(x_train_stand)

#procedura per ols model ------------------------------------------------------------------------------------------------------------

ols_model = sm.OLS(y, x_train_stand)
ols_results = ols_model.fit(cov_type='HC1') 
print(ols_results.summary())

reg = linear_model.Ridge(alpha='0.0001')
#reg = linear_model.LinearRegression()
reg= reg.fit(x_train_stand,y)

#forecast ------------------------------------------------------------------------------------------------------------

ypredTrain = reg.predict(x_train_stand)

print('r2 train: ',r2_score(y,ypredTrain))
print('mse train: ',mean_squared_error(y,ypredTrain))

scores=cross_validate(reg, x_train_stand, y, cv=5,scoring=('r2', 'neg_mean_squared_error'),return_train_score=True)
print('r2 cv: ', scores['test_r2'].mean())
print('mse cv: ', abs(scores['test_neg_mean_squared_error'].mean()))


#modellazione dei dati test set------------------------------------------------------------------------------------------------------------
xTestExpUsa= df.iloc[0:450,1:2]
xTestExpUsa = np.array(xTestExpUsa)
xTestExpEu=df.iloc[0:450,3:4]
xTestExpEu = np.array(xTestExpEu)
xTestImportChina=xTestExpUsa+xTestExpEu

polynomial_features= PolynomialFeatures(degree=2)
xTestImportChina = polynomial_features.fit_transform(xTestImportChina)

xTestBimestri=df.iloc[0:450,13:18]
xTestBimestri = np.array(xTestBimestri)

xTestUsa=df.iloc[0:450,0:1]
xTestUsa = np.array(xTestUsa)
xTestBimInfExpUsa=xTestBimestri*xTestUsa

xTestEu=df.iloc[0:450,1:2]
xTestEu = np.array(xTestEu)
xTestBimInfExpEu=xTestBimestri*xTestEu

xTestPrecUsa=df.iloc[0:450,7:8]
xTestPrecUsa = np.array(xTestPrecUsa)
xTestBimInfPrecUsa=xTestBimestri*xTestPrecUsa

xTestPrecEu=df.iloc[0:450,9:10]
xTestPrecEu = np.array(xTestPrecEu)
xTestBimInfPrecEu=xTestBimestri*xTestPrecEu

xTestTempUsa=df.iloc[0:450,8:9]
xTestTempUsa = np.array(xTestTempUsa)
xTestBimInfTempUsa=xTestBimestri*xTestTempUsa

xTestTempEu=df.iloc[0:450,10:11]
xTestTempEu = np.array(xTestTempEu)
xTestBimInfTempEu=xTestBimestri*xTestTempEu

xTestOpenInterest=df.iloc[0:450,4:5]
xTestOpenInterest = np.array(xTestOpenInterest)
xTestBimInfOpenInterest=xTestBimestri*xTestOpenInterest

xTest= df.iloc[0:450,0:1]
xTest1= df.iloc[0:450,2:3]
xTest2= df.iloc[0:450,4:5] #openInterest
xTest3= df.iloc[334:450,6:11]
xTest4= df.iloc[0:450,11:12] #stockWorld
xTest5= df.iloc[0:450,12:13] #stockUsa
xTest6= df.iloc[334:450,13:18]

polynomial_features= PolynomialFeatures(degree=2)
xTest = polynomial_features.fit_transform(xTest)

polynomial_features= PolynomialFeatures(degree=2)
xTest1 = polynomial_features.fit_transform(xTest1)

polynomial_features= PolynomialFeatures(degree=3)
xTest2 = polynomial_features.fit_transform(xTest2)

polynomial_features= PolynomialFeatures(degree=3)
xTest4 = polynomial_features.fit_transform(xTest4)

polynomial_features= PolynomialFeatures(degree=3)
xTest5 = polynomial_features.fit_transform(xTest5)



xTestImportChina=xTestImportChina.tolist()
xTestImportChina = DataFrame (xTestImportChina,columns=['ImportChina','ImportChina1','ImportChina2'])

xTest=xTest.tolist()
xTest = DataFrame (xTest,columns=['expUsa','expUsa1','expUsa2'])

xTest1=xTest1.tolist()
xTest1 = DataFrame (xTest1,columns=['expEu','expEu1','expEu2'])

xTest2=xTest2.tolist()
xTest2 = DataFrame (xTest2,columns=['openInt','openInt1','openInt2','openInt3'])

xTest4=xTest4.tolist()
xTest4 = DataFrame (xTest4,columns=['sw','sw1','sw2','sw3'])

xTest5=xTest5.tolist()
xTest5 = DataFrame (xTest5,columns=['su','su1','su2','su3'])

xTestBimInfExpUsa=xTestBimInfExpUsa.tolist()
xTestBimInfExpUsa = DataFrame (xTestBimInfExpUsa,columns=['bim1*expUsa','bim2*expUsa','bim3*expUsa','bim4*expUsa','bim5*expUsa'])
xTestBimInfExpEU=xTestBimInfExpEu.tolist()
xTestBimInfExpEu = DataFrame (xTestBimInfExpEu,columns=['bim1*expEu','bim2*expEu','bim3*expEu','bim4*expEu','bim5*expEu'])

xTestBimInfPrecUsa=xTestBimInfPrecUsa.tolist()
xTestBimInfPrecUsa = DataFrame (xTestBimInfPrecUsa,columns=['bim1*precUsa','bim2*precUsa','bim3*precUsa','bim4*precUsa','bim5*precUsa'])
xTestBimInfPrecEu=xTestBimInfPrecEu.tolist()
xTestBimInfPrecEu = DataFrame (xTestBimInfPrecEu,columns=['bim1*precEu','bim2*precEu','bim3*precEu','bim4*precEu','bim5*precEu'])

xTestBimInfTempUsa=xTestBimInfTempUsa.tolist()
xTestBimInfTempUsa = DataFrame (xTestBimInfTempUsa,columns=['bim1*tempUsa','bim2*tempUsa','bim3*tempUsa','bim4*tempUsa','bim5*tempUsa'])
xTestBimInfTempEu=xTestBimInfTempEu.tolist()
xTestBimInfTempEu = DataFrame (xTestBimInfTempEu,columns=['bim1*tempEu','bim2*tempEu','bim3*tempEu','bim4*tempEu','bim5*tempEu'])

xTestBimInfOpenInterest=xTestBimInfOpenInterest.tolist()
xTestBimInfOpenInterest = DataFrame (xTestBimInfOpenInterest,columns=['bim1*openInterest','bim2*openInterest','bim3*openInterest','bim4*openInterest','bim5*openInterest'])

xTest=xTest.iloc[334:450,1:2]
xTest=xTest.join(xTestImportChina.iloc[334:450,1:2])
xTest=xTest.join(xTest1.iloc[334:450,1:2])
xTest=xTest.join(xTest2.iloc[334:450,1:4])
xTest=xTest.join(xTest3)
xTest=xTest.join(xTest4.iloc[334:450,1:4])
xTest=xTest.join(xTest5.iloc[334:450,1:4])
xTest=xTest.join(xTest6)
xTest=xTest.join(xTestBimInfExpUsa)
xTest=xTest.join(xTestBimInfExpEu)
#xTest=xTest.join(xTestBimInfPrecUsa)
#xTest=xTest.join(xTestBimInfPrecEu)
#xTest=xTest.join(xTestBimInfTempUsa)
#xTest=xTest.join(xTestBimInfTempEu)
xTest=xTest.join(xTestBimInfOpenInterest)



yTest= df.iloc[334:450,19:20]

#print(xTest)

#stardadizzazione dei dati test set------------------------------------------------------------------------------------------------------------

scaler = MinMaxScaler(feature_range=(-1,1))

x_test_stand=(scaler.fit_transform(xTest))

#modello dati test set------------------------------------------------------------------------------------------------------------    

x_test_stand, ytest = np.array(x_test_stand), np.array(yTest)
x_test_stand = sm.add_constant(x_test_stand)

ypredTest = reg.predict(x_test_stand)

print('r2 test: ',r2_score(ytest,ypredTest))
print('mse test: ',mean_squared_error(ytest,ypredTest))

i=0
for i in range(83):
    print(ytest[i],ypredTest[i])


#i=0
#for i in range(38):
    #print(reg.coef_[0,i])

i=0
for i in range(37):
    print(xTest.iloc[2:3,i:(i+1)])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.870
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     96.88
# Date:                Mon, 07 Jun 2021   Prob (F-statistic):          1.81e-143
# Time:                        15:54:40   Log-Likelihood:                -1608.0
# No. Observations:                 334   AIC:                             3292.
# Df Residuals:                     296   BIC:                             3437.
# Df Model:                          37
# Covariance Type:                  HC1
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        431.2127     44.982      9.586      0.000     343.050     519.376
# ...

# %% [markdown]
# # 0
